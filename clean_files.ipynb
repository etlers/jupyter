# %%
import os

def print_files_in_dir(root_dir, prefix):
    files = os.listdir(root_dir)
    for dir in files:
        filename = os.path.join(root_dir, dir)
        print(filename)
        # os.rename(filename, filename.replace(" - 구글검색 토렌트노리", ""))
        # list_filenm = filename.split(" (")[0]
        # if len(list_filenm) == 1:
        #     new_filename = filename.split(" (")[0] + ".mp3"
        # else:
        #     new_filename = filename[:len(filename)-14].strip() + ".mp3"
        # os.rename(filename, new_filename)


if __name__ == "__main__":
    root_dir = "/Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라"
    print_files_in_dir(root_dir, "")
# Out:
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2006년 연간 TOP 100 (192k)
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2002년 연간 TOP 100 (192k)
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2012년 연간 TOP 100 (320k)
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2016년 연간 TOP 100 (320k)
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/.DS_Store
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2010년 연간 TOP 100 (192k)
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2011년 연간 TOP 100 (192k)
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2003년 연간 TOP 100 (192k)
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2007년 연간 TOP 100 (192k)
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2020년 연간 TOP 100 (320k)
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2017년 연간 TOP 100 (320k)
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2013년 연간 TOP 100 (320k)
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2015년 연간 TOP 100 (320k)
# ...

# %%
def print_files_in_dir(root_dir, prefix):
    files = os.listdir(root_dir)
    for file in files:
        path = os.path.join(root_dir, file)
        if "MINO" in path:
            os.remove(path)
            continue
        
        if os.path.isdir(path):
            print_files_in_dir(path, prefix + "    ")
        else:
            # new_filenm = file.replace(" - 구글검색 토렌트노리", "")
            # new_path = os.path.join(root_dir, new_filenm)
            # os.rename(path, new_path)
            print(path)
            
if __name__ == "__main__":
    root_dir = "/Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라"
    print_files_in_dir(root_dir, "")
# Out:
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2006년 연간 TOP 100 (192k)/정재욱 4집12 가만히 눈을 감고.mp3
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2006년 연간 TOP 100 (192k)/이승철 8집11 떠나지마.mp3
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2006년 연간 TOP 100 (192k)/거미01 그대 돌아오면.mp3
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2006년 연간 TOP 100 (192k)/가비엔제이 2집01 그녀가 울고 있네요.mp3
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2006년 연간 TOP 100 (192k)/버즈 3집02 My Darling (End).mp3
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2006년 연간 TOP 100 (192k)/버즈 Single01 사랑은 가슴이 시킨다 (CF - KTF 도시락).mp3
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2006년 연간 TOP 100 (192k)/플라이 투 더 스카이 6집02 피(避).mp3
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2006년 연간 TOP 100 (192k)/홍경민 7집05 사랑..참.mp3
# /Users/etlers/Music/[멜론] 2000 - 2020 연간 TOP 100 총망라/2006년 연간 TOP 100 (192k)/럼블피쉬 Single01 I GO.mp3
# ...
