# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://en.wikipedia.org/wiki/Kevin_Bacon")
bs = BeautifulSoup(html, "html.parser")
for link in bs.findAll("a"):
    if "href" in link.attrs:
        print(link.attrs["href"])

# %%
import pandas as pd
import requests
import lxml.html as lh
from bs4 import BeautifulSoup as bs

# %%
list_headline = []

def get_news_headline(page):
    
    def except_word(headline):
        result_tf = False
        
        list_word = ["이혼", "결혼"]
        for word in list_word:
            if word in headline:
                result_tf = True
                break
        
        return result_tf
        
    base_url = f"https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101&page={page}"
    response = requests.get( base_url, headers={"User-agent": "Mozilla/5.0"} )
    soup = bs(response.text, 'html.parser')
    list_news = str(soup.findAll("div", {"id": "main_content"})).split('\n')
    for row in list_news:
        if '<a class="cluster_text_headline nclicks' in row:
            filtered_row = row.replace('<a class="cluster_text_headline nclicks(cls_eco.clsart)"',"").replace("</a>","")
            str_href = filtered_row.split(">")[0].strip()
            str_headline = filtered_row.split(">")[1].strip()
            if except_word(str_headline): continue
            list_headline.append(str_headline)
            
for idx in range(5):
    get_news_headline(idx+1)
    
print(list_headline)

df_headline = pd.DataFrame(list_headline, columns=["헤드라인"])
print(df_headline)

# %%
base_url = f"https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101"
response = requests.get( base_url, headers={"User-agent": "Mozilla/5.0"} )
soup = bs(response.text, 'html.parser')
list_news = str(soup.findAll("div", {"id": "main_content"})).split('\n')
for row in list_news:
    if ('<span class="cluster_head_sub_topic">' in row or
        '<a class="cluster_text_headline nclicks(cls_eco.clsart)"' in row or
        '<div class="cluster_text_lede">' in row or
        '<a class="cluster_head_more nclicks(cls_eco.clstitle)"' in row or
        '<span class="cluster_head_sub_topic">' in row):
        print(row)

# %%
import time
import requests

def send_message_to_slack(text): 
    url = "https://hooks.slack.com/services/T01AS2H6KU2/B022R8HK7U2/ju9pSY0oBlIHDwDB" 
    pyload = { "text" : text } 
    response = requests.post(url, json=pyload)
    print(response)

def except_word(headline):
    result_tf = False

    list_word = [
        "이혼", "결혼" "부동산", "LH", "한국주택공사", "분양", "전세", "월세", "전월세", "민간임대", "공공임대" ,"다주택", 
        "사망", "산재", "상품권", "쿠폰", "유니폼", "아파트", "할인", "국토부"
    ]
    for word in list_word:
        if word in headline:
            result_tf = True
            break

    return result_tf

def replace_word(word):
    list_remove = [
        '<span class="cluster_head_sub_topic', "</span>", "</a>", "</div>", "…", "\'", "/"
    ]
    for val in list_remove:
        word = word.replace(val, "")
    word = word.replace("&amp;","&").replace("銀","은행").replace("▲","").replace("&gt;",">").replace("&lt;","<")
    word = word.replace("&eq;","=").replace('"', "'")

    return word

list_filtered = []

def get_news():
    base_url = f"https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101"
    response = requests.get( base_url, headers={"User-agent": "Mozilla/5.0"} )
    soup = bs(response.text, 'html.parser')
    list_div_class = [
        "_persist",
        "section_body",
    ]
    list_check_tag = [
        '<div class="cluster_text_lede">',
        '<span class="cluster_head_sub_topic">',
        '<a class="cluster_thumb_link nclicks(cls_eco.clsart)"',
        '<a class="cluster_text_headline nclicks(cls_eco.clsart)"',
    ]

    for div_class in list_div_class:
        list_news = str(soup.findAll("div", {"class": div_class})).split('\n')
        for row in list_news:
            if except_word(row): continue
            for tag in list_check_tag:
                if tag in row:
                    filtered_row = replace_word(row.replace(tag,""))
                    try:
                        filtered_row = filtered_row.split('">')[1]
                    except:
                        pass
                    filtered_row = filtered_row.strip()
                    if len(filtered_row) == 0: continue
                    if (filtered_row[:1] == '"' or filtered_row[:1] == '“'):
                        filtered_row = filtered_row[1:]
                    list_filtered.append(filtered_row)
          
for idx in range(5):
    get_news()
    time.sleep(10)
    
list_filtered = list(set(list_filtered))
list_filtered = sorted(list_filtered)
df_news = pd.DataFrame(list_filtered, columns=["헤드라인"])

msg = ""
for row in list_filtered:
    msg += row + "\n"
print(msg)
# send_message_to_slack(msg)
# Out:
# 21일(현지시간) 중국 국무원은 비트코인 채굴과 거래를 단속하겠다는 내용의 성명서를 발표했다. 바로 전날에는 미국 재무부가 1만 달러 넘는 가상자산(
# 22일 오전 국내 암호화폐 거래소에서 비트코인이 4800만원대에 거래 중이다. 가상화폐 거래소 빗썸에 따르면 이날 오전 10시 8분 현재 1비트코인 가격
# 24일부터 1만원 돌려준다 배달앱으로 음식 4번 주문하면
# 2차  농식품펀드 상반기 805억원 조성
# 4246억원 전주하가 재개발 따내 누적 1조2919억 재무건전성 덕분작년 최대 실적 이어 올해도 순항 현대건설이 전주에서 4246억원 규모 재개발 시공
# 4월 항만 수출입 물동량 7.4%↑자동차 물동량 57.5% 증가
# 4월 항만 수출입 물동량 관리
# 4월 항만 수출입 물동량, 전년 동월 대비 7.4%↑
# 6월 제조업 전망 3개월 만에 상승반도체·차·철강·바이오헬스↑ 산업연
# 6월 제조업 전망 맑음전월 기준 比 3개월만에 상승"
# IBK기업은행은 윤종원 행장이 지난 21일 취임 이후 100번째 영업점 방문을 했다고 23일 밝혔다. 윤 행장은 취임 후 전국 영업점을 방문하며 직원들을
# KB·하나·우리 무더기 퇴출 현실화되나
# KB·하나·우리금융 "가상화폐 거래소와 계약 안 한다"
# KB·하나·우리금융지주의 은행들이 암호화폐거래소와 사실상 실명 계좌 발급 등의 제휴 계약을 체결할 계획이 없는 것으로 알려졌다. 자금 세탁, 해킹 등에
# KB·하나·우리은행 "암호화폐 거래소 제휴 사실상 어렵다"
# LG 올레드 에보 전문매체 "베스트바이 TV" 1위
# LG 올레드 에보, TV 명가 일본 오디오 전문 매체서 호평
# LG 올레드 에보, 日 오디오 전문 매체서 호평
# LG 올레드 에보, 日 전문매체 베스트바이 TV 1위
# LG전자가 올해 출시한 차세대 올레드 TV인 LG 올레드 에보(OLED evo)가 일본 최고 전문가들로부터 압도적 화질을 인정받았다고 23일 밝혔다. 일
# LG전자가 올해 출시한 차세대 올레드 TV인 LG 올레드 에보가 일본 최고 전문가들로부터 압도적 화질을 인정받았다. 23일 LG전자에 따르면 일본 오
# LG전자가 올해 출시한 차세대 올레드 TV인 LG 올레드 에보가 일본 최고 전문가들로부터 화질을 인정받았다. 23일 LG전자에 따르면 일본 AV(Audi
# LG전자가 일본에서 소니, 파나소닉 등 현지 브랜드들을 제치고 올레드(OLED·유기발광다이오드) TV 최고 제품으로 선정됐다. 23일 업계에 따르면 일본
# LG전자는 올해 출시한 차세대 올레드(OLED·유기발광다이오드) TV인 LG 올레드 에보(OLED evo)가 일본에서 전문가들로부터 인정받았다고 23일
# NH농협은행 마케팅부문 남재원 부행장과 개인고객부 직원들은 지난 21일 대학생봉사단 N돌핀과 함께 경북 예천군에 소재한 풍양초등학교를 방문하여 ‘이동금융
# NH농협은행, 금융소외지역 찾아 이동금융교육 펼쳐
# NH농협은행, 금융소외지역 찾아가는 ‘이동금융교육’ 실시
# NH농협은행은 남재원 마케팅부문 부행장과 개인고객부 직원들은이 지난 21일 대학생봉사단 ‘N돌핀’과 함께 경북 예천군에 소재한 풍양초등학교를 방문해 ‘이
# NH농협은행은 남재원 마케팅부문 부행장과 개인고객부 직원들이 지난 21일 대학생봉사단 N돌핀과 함께 경북 예천군에 소재한 풍양초등학교를 방문해 ‘이동금융
# NYT 칼럼서 비판"투기 수단 외에 쓰이는 곳은 돈세탁뿐" (뉴욕=연합뉴스) 고일환 특파원 = 노벨경제학상 수상자인 폴 크루그먼 뉴욕시립대 교수가 비트
# P4G 정상회의 달군다6일간 운영 녹색미래주간 24일 개막
# [중기부 2021년 모태펀드 2차 출자사업 벤처투자조합(펀드) 선정 완료] 중소벤처기업부가 2021년 모태펀드 2차 출자사업의 벤처투자조합(펀드)
# `넥쏘` 인기에 수소차 보조금 빠른 소진추경 불가피
# ‘지분적립형 주택’에 40년 만기 초장기 모기지(주택담보대출)를 연계하는 방안이 추진된다. 내 집 마련에 나서는 청년층의 대출 원리금 부담을 낮춰주려는
# 【 앵커멘트 】 11년 전 오늘은 비트코인이 처음으로 결제 수단으로 사용된 날입니다. 무려 비트코인 1만 개를 내고 겨우 피자 2판을 구매했던 건데 지금
# 中 "암호화폐 단속" 한마디에비트코인 등 일제히 폭락
# 中 류허 "비트코인 채굴·거래 타격할 것"···디지털 위안화 위해 암호화폐 죽이나
# 中 정부 “비트코인 채굴·거래 단속 강화할 것”
# 日 매체, LG 올레드 에보 호평
# 日도 반했다소니·파나소닉 제치고 1위 오른 LG 올레드
# 美 투자 한국법인 1000개 9만명
# 美 투자 한국법인 1000개..현지 고용인원은 9만명 육박
# 美·中 강경책에 비트코인 4600만원대알트코인 하락세 심화 [코인시세]
# 車 좋아하는 초등·중학생 찾습니다"..현대차, 미래차 학교 진행
# 韓-美 정상, 해외원전시장 공동진출 합의
# 일론 머스크 테슬라 최고경영자(CEO)가 또다시 도지코인 지지를 암시하는 트윗을 게재했다. 머스크 CEO는 22일(현지시간) 자신의 트위터에 예수님이 도
# 입방정 머스크 이번엔 예수 이미지까지 동원"가상화폐 지지"
# 전기차업체 테슬라의 CEO 일론 머스크가 22일(현지시간) 자신의 트위터에 올린 사진 [출처 : 일론 머스크 트위터] 최근 폭락세를 보였던 비트코인이 잠
# 전기차에 이어 수소차 구매보조지원금도 빠르게 소진되고 있는 것으로 집계됐다. 일부 지역에서는 보조금 배정 규모보다 더 많은 신청이 접수돼 추가경정예산(추
# 전력연구원 용역 입찰담합한 업체들공정위, 과징금 3200만원
# 전체 직원·금발심 분과위원장 참여 워크숍 (서울=연합금융위원회는 "신종 코로나바이러스 감염증(코로나19) 위기 대응과정에서 불가피하게 증가한 유동성의 질
# 전해철 행안부 장관 "P4G 서울정상회의" 특별세션 참여
# 전해철 행안장관, P4G 서울 정상회의 특별세션 참여
# 정부가 항공기 조종사와 객실승무원의 피폭량 기준을 강화한다. 국토교통부는 우주방사선으로부터 항공기 조종사와 객실승무원(이하 항공승무원)의 건강 보호를 강
# 정책금융 신청 때 금융거래 확인서 제출 안 해도 돼요
# 제조업 개선세 주춤했다 회복6월 전망 3개월만에 상승
# 조 바이든 미 대통령과 악수하는 문재인 대통령 (사진=뉴스1) [이데일리 김국배 기자] 한국과 미국이 해외 원전 시장에 공동으로 진출하기로 합의했다. 한
# 종이 서류를 제출하지 않아도 중소벤처기업진흥공단의 정책자금 신청이 가능해졌다. 23일 중진공은 금융거래 조회 시스템 도입 및 금융거래확인서 제출 전면 폐
# 종이서류 없이도 중진공 정책자금 신청 가능
# 중 당국 "비트코인 타격하겠다"주요 코인들 10% 이상 ↓
# 중국발 악재에 눌린 비트코인 3만8천달러 턱걸이
# 중소벤처기업부와 문화체육관광부, 과학기술정보통신부, 환경부, 국토교통부, 교육부 6개 부처는 2021년 모태펀드 2차 출자사업의 자펀드 선정을 마쳤다고
# 중소벤처기업진흥공단은 금융거래 조회 시스템 도입, 금융거래확인서 제출 전면 폐지에 따라 기업의 서류제출 부담을 낮추고 정책자금 접근성 강화한다고 23일
# 중소벤처기업진흥공단은 자체 금융거래 조회 시스템을 도입하고 기업의 금융거래 확인서 제출을 전면 폐지한다고 23일 밝혔다. 그동안 중소벤처기업이 정책자금을
# 중진공 20억원 절감 기업 금융거래확인서 서류제출 전면 폐지
# 중진공, 기업 금융거래확인서 서류제출 전면 폐지
# 중진공, 종이서류 없이 정책자금 심사 비용 20억원 절감 기대
# 지금까지 정책자금 신청을 위해서는 신청기업이 은행 등 거래 금융기관에서 직접 금융거래 확인서를 발급받아 중소벤처기업진흥공단에 제출해야 했다. 하지만 이제
# 지난달 국내 항만에서 처리한 수출입 물동량이 7.4% 증가한 것으로 나타났다. 23일 해양수산부에 따르면 지난달 전국 무역항에서 처리한 항만 물동량은 총
# 행정안전부는 전해철 장관이 오는 24일 서울 동대문디자인플라자(DDP)에서 글로벌 탄소중립을 위한 지방정부의 역할을 주제로 열리는 P4G(녹색성장 및
# 현대건설 전주 하가구역 재개발사업 수주도시정비사업 수주 1조원 돌파
# 현대건설, 4246억원 규모 전주 하가구역 재개발 시공권 확보올해 누적 수주액 1.3조 달성
# 현대건설, 도시정비 수주 벌써 1조 돌파
# 현대건설, 올해 도시정비사업 수주 ‘1조원’ 돌파
# 현대건설, 전주 재개발사업 시공권 따내올해 수주액 1조원 돌파
# 현대건설, 전주 하가구역 재개발사업 수주···수주액 1조 돌파
# 현대건설, 전주 하가구역 재개발사업 수주도시정비사업 수주 1조원 돌파
# 현대건설이 전북 전주 허가구역 재개발정비사업 시공권을 획득하며 올해 누적 수주액 1조원을 돌파했다고 23일 밝혔다. 현대건설에 따르면 전주 허가구역 재개
# 현대건설이 전북 전주에서 4,200억원 규모의 재개발 사업을 수주하며 올해 도시정비사업 수주액 1조원을 돌파했다. 현대건설은 지난 22일 전주 하가구역
# 현대건설이 전주 하가구역 재개발정비사업의 시공권을 획득하며 올해 누적 수주 금액 1조원을 돌파했다고 23일 밝혔다. 전주 하가구역 재개발정비사업 조감도.
# 현대건설이 지난 22일 전주 하가구역 재개발정비사업의 시공권을 따내며 올해 누적 수주 금액 1조원을 돌파했다고 밝혔다. 전북 전주 하가구역 재개발정비사업
# 현대자동차가 오는 24일부터 다음달 18일까지 중학교 자유학기제 특화 진로교육 및 초등학교 창의적 체험활동 프로그램인 현대차와 함께 꿈을 키우는 미래
# 현대자동차가 올해 2학기 중학교 자유학기제 특화 진로교육과 초등학교 창의적 체험활동 프로그램 ‘현대차와 함께 꿈을 키우는 미래 자동차 학교’에 참여할 학
# 현대자동차는 중학교 자유학기제 특화 진로교육 및 초등학교 창의적 체험활동 연계 프로그램인 미래 자동차 학교 2학기 참여 모집을 시작한다고 23일 밝혔
# 현대자동차의 수소전기차 넥쏘( 사진 )가 올해 하반기 글로벌 누적 판매량이 2만대를 돌파할 것으로 전망된다. 넥쏘 판매량이 늘면서 일부 지방자치단체의 경
# 현대차 2021년 2학기 미래 자동차 학교 모집
# 현대차 ‘미래 자동차 학교’ 운영
# 현대차, 2학기 ‘미래 자동차 학교’ 참여할 초·중등학교 모집
# 현대차, 미래 자동차 학교 모집"자동차 꿈나무 모여라"
# 현대차, 청소년 진로탐색 미래 자동차 학교 2학기 모집
# 현대차, 초·중 미래 자동차 학교 2학기 참가학교 모집
# 현대차가 오는 24일부터 다음달 18일까지 중학교 자유학기제 특화 진로교육 및 초등학교 창의적 체험활동 프로그램 현대차와 함께 꿈을 키우는 미래 자동차

# %%
# https://hooks.slack.com/services/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

import requests

def send_message_to_slack(text): 
    url = "WebHook Url" 
    pyload = { "text" : text } 
    requests.post(url, json=pyload)
    
send_message_to_slack("Test WebHook Message")
