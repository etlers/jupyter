# %%
import pandas as pd

yaml_file = open("jongmok.yaml", 'w', encoding="utf-8")

df_jongmok = pd.read_csv("jongmok_list.csv", encoding="cp949")
df_jongmok.rename(columns={"단축코드": "JONGMOK_CD", "한글 종목약명": "JONGMOK_NM"}, inplace=True)
df_jongmok = df_jongmok[["JONGMOK_CD","JONGMOK_NM"]]

for cd, nm in df_jongmok.iterrows():
    yaml_file.write(cd + ": " + nm + "\n")
# Out:
# 0 JONGMOK_CD     098120
# JONGMOK_NM    마이크로컨텍솔
# Name: 0, dtype: object
# 1 JONGMOK_CD    131100
# JONGMOK_NM    스카이이앤엠
# Name: 1, dtype: object
# 2 JONGMOK_CD    009520
# JONGMOK_NM     포스코엠텍
# Name: 2, dtype: object
# 3 JONGMOK_CD    095570
# JONGMOK_NM    AJ네트웍스
# Name: 3, dtype: object
# 4 JONGMOK_CD    006840
# JONGMOK_NM     AK홀딩스
# Name: 4, dtype: object
# 5 JONGMOK_CD    282330
# JONGMOK_NM    BGF리테일
# Name: 5, dtype: object
# 6 JONGMOK_CD    027410
# JONGMOK_NM       BGF
# Name: 6, dtype: object
# 7 JONGMOK_CD     138930
# JONGMOK_NM    BNK금융지주
# Name: 7, dtype: object
# 8 JONGMOK_CD    001465
# JONGMOK_NM      BYC우
# Name: 8, dtype: object
# 9 JONGMOK_CD    001460
# JONGMOK_NM       BYC
# Name: 9, dtype: object
# 10 JONGMOK_CD    001045
# JONGMOK_NM       CJ우
# Name: 10, dtype: object
# 11 JONGMOK_CD      00104K
# JONGMOK_NM    CJ4우(전환)
# Name: 11, dtype: object
# 12 JONGMOK_CD    001040
# JONGMOK_NM        CJ
# Name: 12, dtype: object
# 13 JONGMOK_CD     011155
# ...
